# %% [markdown]
#     A Karnaugh map (K-map) is a visual tool used to simplify Boolean algebra
#     expressions without relying on complex mathematical rules. It translates a
#     standard truth table into a specific grid format where you can visually
#     group adjacent outputs to find the smallest, most efficient circuit design.
#
# How the Grid Works
#     The map is arranged to that adjacent rows and columns differ by only one
#     variable value at a time.
#     - Instead of standard binary counting (00, 01, 10, 11), the axes use GRAY
#       CODE: 00, 01, 11, 10.
#     - This specific ordering ensures that any movement up, down, left, or right
#       represents a change in exactly on variable, making visual simplification
#       possible.
#
#
# The Rules of Grouping (Circling)
#     To minimise an expression, you draw circles (or rectangles) around the 1s
#     on the grid. Every valid circle you draw becomes a single term in your final
#     , simplified Boolean equation.
#     - RULE of 1s: Circles can only cover 1s (and "Don't Cares"), never 0s.
#     - Power of 2 Size: The extend of the circle in both directions must be a
#       power of 2. You can group 1, 2, 4, 8 or 16 cells together. But you can
#       never group 3, 5, or 6 cells.
#     - BIGGER IS BETTER: The larger the circle, the fewer variables will be in
#       that resulting term leading to a smaller circuit.
#     - COMPLETE COVERAGE: You must cover all the 1s in the map, and a single 1 can
#       be covered by multiple overlapping circles if it helps those circles larger.
#     - WRAPPING: The edges of the map wrap around. The top row is adjacent to the
#       bottom row, and the far-left column is adjacent to the far right-column.
#
# Using "Don't Cares" (X)
#     In some circuit designs, certain input combinations will never physically
#     occur, so you do not care what the output is. These are marked as an "X" on
#     the map. You can selectively treat an X as a 1 if it helps you draw a larger
#     circle around existing 1s, or treat it as a 0 if it doesn't help. ...

# %% [markdown]
#     ... dealing exclusively with COMBINATIONAL LOGIC. In combinational circuits,
#     the output is strictly determined by the current inputs. If you change the
#     input, the output changes instantly (ignoring minor propagation delays).
#     There is no memory, no history, and no concept of "time".
#
#     ... introduces SEQUENTIAL LOGIC, which completely changes the game by adding
#     TIME and MEMORY.
#
#     ...
#
#
# ---
# 1. The Magic of Feedback
#     To make a circuit "remember" something, you have to take its output wire and
#     loop back into its own input. This is called FEEDBACK. Because the gate is
#     now feeding itself, the circuit can hold onto a state (1 or 0) even after
#     the original input that caused it has turned off.
#
#
# 2. The SR Latch (Set-Reset)
#     The simplest memoryu circuit is the SR Latch, usually built using two
#     cross-coupled NOR gates or NAND gates.
#     - Set (S): Pushing ths input

# %% [markdown]
#    Each row says: "if the circuit is currently in this state NOW, after one gate
#    delay it moves to state NEXT" A stable state is where NOW = NEXT (outputs
#    can't change). ... see where the circuit settles -- or if it oscillates
#    forever.
#
# ---
# Propagation Delay
#    Every gate takes a small time (t_d) to compute its output. During this delay,
#    the output holds its old value. This is modeled by the `switch and delay`
#    model.
#
# Feedback
#    When a gate's output is connected back to its own input (directly or via
#    other gates), the circuit has feedback. Feedback can create memory (latches)
#    or oscillation.
#
# Stable vs Unstable States
#     A state is STABLE if the circuit's outputs don't change after one gate delay
#     (NOW outpus = NEXT outputs). Unstable states transition to other states
#     until a stable state is reached -- or oscillation ocucurs.
#
# Oscillation
#     If two unstable states point to each other, the circuit flips between them
#     forever. Example: NAND with A=1 and feedback -- R flips 0->1->0->1... This
#     is how ring oscillators work.
#
# ...
#
# The NOR/NAND Latch (SR-Latch)
#     Two cross-coupled NOR (or NAND) gates create a bistable circuit -- it has
#     TWO stable states for the same input. This is the basis of memory: the
#     circuit `remembers` which stable state it fell into.
#
# Static Hazard / Glitch
#     When an input chaanges, different signal paths through a circuit have
#     different delays. The output may briefly glitch to the wrong value before
#     settling. This is a static hazard -- the output should stay constant but
#     briefly blips.

# %% [markdown]
# 1. What does "Latch" mean?
#     ... a latch implies a STABLE, SELF-SUSTAINING STATE.
#
#     Think of a mechanical door latch. Once it clicks into place, you can let go
#     of the handle, and the door stays shut. In digital logic, once you pulse the
#     `Set` wire to a `1`, the internal feedback loops "locks" the output to `1`.
#     Even after the `Set` wire goes back to `0`, the circuit sustains that output
#     indefinitely until someone explicitly pulses the `Reset` wire. That ability
#     to hold a stable state without continuous input is what gives it "memory."
#
#
# 2. Is Q ...
#     Q is the official memory state. If Q=1, we say "the latch is storing a 1."
#        - If Q = 0, we say "the latch is storing a 0."
#     Q' (Q-inverse) is just a convenient by-product. Because of how the internal
#     `NOR` or `NAND` gates are cross-coupled, the circuit naturally produces the
#     exact opposite of Q on the other side. Hardware engineers almost always need
#     the inverted version of a signal for the next stage of their circuit, so the
#     latch simply provides both for free. But when evaluatng what data is
#     actually saved, you only look at $Q$.

# %% [markdown]
# ---

# %% [markdown]
# (Types of Circuits)
#     A few keywords to remember:
#
#     - COMBINATORIAL: output is a combination of ONLY INPUTS
#     - SEQUENTIAL: output is a combination of INPUTS AND PREVIOUS OUTPUTS (we
#       need a transition table or state digram, it needs some notion of time)
#     - ASYNCHRONOUS: output will have correct value after an UNDEFINED amount of
#       time.
#     - SYNCHRONOUS: output will have correct value after a DEFINED amount of
#       time (a clock signal tells us time)

# %% [markdown]
#    ... terminilogy overlaps... meaning changes ... when hardware... In 40001,
#    "synchronous" and "asynchronous" are strictly about physical timing
#    coordination, specifically whether a circuit uses a global CLOCK PULSE. A
#    SYNCHRONOUS circuit relies on a steady electronic heartbeat; its components
#    (like registers and flip-flops) are only allowed to capture or change their
#    values exactly when the clock "ticks" (usually on the rising edge of the
#    signal). Because the clock's frequency is set by the designer, the time it
#    takles for the system to process data and output a result is strictly
#    defined and predictable.
#
#    Conversely, an ASYNCHRONOUS hardware circuit has no heartbeat. As soon as you
#    alter the inputs to a logic gate, the electrons immediately start flowing to
#    change the output. The output will eventually settle to the correct value,
#    but the exact time it takes depends purely on the physical resistance of the
#    wires, the temperatures, and the specific delays of the logic gates involved.
#    Because there is no central clock dictating exactly when the output is
#    officially ready, the timing is considered "undefined"--the system just
#    updates as fast as physics allows.

# %% [markdown]
# ---

# %% [markdown]
#    ... takes the raw memory we just built with latches and makes it predictable
#    and safe for a massive CPU to use. The star of the show here is the
#    EDGE-TRIGGERED D-TYPE FLIP-FLOP.
#
#
# 1. The Problem with Latches (Transparency)
#     A standard SR latch (or even an enabled latch) is "transparent." This means
#     that as long as the enable wire (or clock) is high, any tiny glitch or
#     change on the inputs will immediately bleed through and change the outputs.
#     In a complex processor where signals arrive at slightly different times,
#     this transparency causes chaotic, cascading errors.
#
# 2. The D-Type Flip-Flop (Data)
#    To fix the SR latch's annoying "invalid state" (where S=1 and R=1), we
#    connect an inverter between the S and R inputs and tie them to a single wire
#    called D (Data).
#       - If D = 1, it acts like a Set.
#       - If D = 0, it acts like a Reset.
#       - You can never have the invalid 1-1 state because the inverter ensures S
#         and R are always opposites.
#
# 3. EDGE-TRIGGERING (The Holy Grail of Timing)
#    To fix the transparency problem, we use EDGE-TRIGGERING. We design the circuit
#    so that it completely ignores the D input almost all the time. It only "looks"
#    at D and updates Q at the exact microsecond the clock signal ticks from 0 to
#    1 (the RISING EDGE).
#
#    - Once that rising edge has passed, you can flip D wildly all you want, and
#      Q will not care. It is locked until the next rising edge. This allows the
#      CPU to march forward cleanly, one step at a time.
#
#
#
# ---
#
#    ... "reservoir" intuition is perfecrt--the two latches take turns being
#    open/closed, and the output only updates at the handoff moment. Whether that
#    handoff happens at the rising edge or falling edge just depends on which
#    latch gets the inverted clock The principle is identical either way.

# %% [markdown]
# ---

# %% [markdown]
#    Lecture 9 brngs everything together. You are no longer just looking at
#    isolated gates or isolated memory--you are building a complete SYNCHRONOUS
#    DIGITAL SYSTEM (SDS). This is the architectural foundation of a CPU.
#
#    ... exam-focused breakdown of ... focusing on the core concepts of the SDS
#    and Finite State Machines.
#
#
# L09: Part 1: Synchronous Digital Systems (SDS)
#
# What topic is this testing?
#    Understanding the separation of memory and logic, and reading Finite State
#    Machine (FSM) diagrams.
#
# What facts/formulas are needed?
#    - The Anatomy of an SDS: Every synchronous system has two physical parts:
#       1. Memory Elements: A bank of D-type Flip-Flops that hold the CURRENT
#          STATE (e.g., the binary number `10`)
#       2. Combinational Logic: A cloud of basic gates (AND, OR, NOT) that looks
#          at the Current State and any external Inputs to calculate the NEXT
#          STATE.
#
#
#
# ---
# How to read a State Diagram:
#    Each CIRCLE is a state the flip-flop can be in (Q=0 or Q=1).
#    Each ARROW is a transition that happens at the clock edge.
#    The LABEL on each arrow tells you which input values cause that transition.
#    A SELF-LOOP (arrow back to the same state) means the state doesn't change.

# %% [markdown]
# ---

# %% [markdown]
#    In the specification we have state transitions that are unknown. We can deal
#    with these in two different ways:
#
#    1. Design a safe circuit:
#       We can specify the unknown state transitions ourselves to ensure that the
#       circuit operates correctly. For example we could specify that in state 3
#       with input 0 the next state is 0.
#
#    2. Design the smallest possible circuit:
#       We treat all unknown states and transitions as "don't cares" in order to
#       have a good chance of getting the smallest popssible design. However, we
#       then must check that the final circuit works correctly in all instances.

# %% [markdown]
#    ... bridges the gap between raw sequential logic and high-level system design
#    . In L9, you learned how a generic Synchronous Digital System (SDS) uses
#    flip-flops as a "barrier" to safely update its state on a clock edge.
#
#    The first half of L10 focuses entirely on how we formalise the OUTPUTS of
#    these systems. It introduces the two fundamental architectures of Finite
#    State Machines (FSMs) that govern every digital device you use: the MEALY
#    MEACHINE and the MOORE MACHINE.
#
#    ... here's the exam focused breakdown of the first half:
#
#
# ---
# 1. THE MEALY MACHINE (The Reactive System)
#    In a Mealy machine, the system's output is determined by BOTH THE CURRENT
#    STATE AND THE CURRENT INPUTS.
#    - THE DEFINING TRAIT: Because the output relies directly on the inputs, if
#      you flip an input switch, the output can change instantly, without waiting
#      for the next clock tick.
#      ...
#    - USE CASE: Mealy machnes generally require fewer states to solve a probelm
#      because the transitions themselves carry output information.
#
#
#
# 2. THE MOORE MACHINE (The Stable System)
#    In a Moore machine, the system's output is determined ONLY by the CURRENT
#    STATE. The inputs only dictate what the next state will be.
#    - The defining trait: Because the output is tied exclusively to the state
#      memory, flipping an input switch does absolutely nothing to the output
#      until the clock ticks and the state actually changes. It is perfectly
#      synchronised.

# %% [markdown]
# 1. Read an English problem
# 2. Draw the FSM diagram (circles and arrows)
# 3. Convert the diagram into a state table
# 4. Draw karnaugh maps
# 5. Draw the final electrical circuit
#
# Why are you confused right now~?
#    Because the slides you uploaded are doing this process BACKWARDS. The
#    ... starting with a fully build physical circuit (Image 1) and
#    reverse-engineering it into an abstract diagram (image 4) to prove to you that any

# %% [markdown]
# By convention in a Moore Machine, we write the state name (upper) and output
# (lower) in the FSM circles.
#
# --- Desinging the FSM diagram is a process of refining an informal specification
#     into a formal specification of what will be built.
#
#     ... design choices to be made but the task could be done automatically.

# %% [markdown]
# The Danger: When we minimise with K-maps, we mark unused states as don't cares
#    (X) to get smaller equations. But the final circuit gives those X's real
#    values. If the K-map happens to make state 6->7 and 7->6, they form their
#    own little loop. If the circuit powers on in state 6 or 7 (which can
#    happen -- flip-flops start with random values), it's stuck forever and never
#    reaches the real counter.
#
# The Fix: Explicitly force unused states to transition to state 0 (or any used
#    state). This costs a slightly larger circuit, but guarantees the counter
#    always self-corrects within one clock cycle.
