# %% [markdown]
# hello world

# %% [markdown]
#    In FOL, a SIGNATURE ($L$) is the set of "vocabulary" symbols we are allowed
#    to use, consisting of constants (like `saka`), function symbols, and
#    relations (like manages). However, these symbols are just empty labels until
#    we provide an $L$-STRUCTURE ($M$), which acts as the "world" or "model" where
#    the symbols actually mean something. An L-structure is composed of two
#    primary parts: the DOMAIN ($\mathbf{D}$) and the INTERPRETATION ($\mathbf{I}$)
#
#    The DOMAIN is the set of all objects that exist in your universe. In ...
#    You can think of these as the physical "things" (people and teams) in the
#    world. The INTERPRETATION is the mapping that assigns meaning to the symbols
#    in your signature by linking them to those objects. For example, $I(saka) = o_1$
#    tells us that the constant "saka" refers to the specific object $o_1$ in the
#    domain,
#
#    Relations are interpreted as sets of objects (for unary relations) or sets of
#    pairs (for binary relations). In the image, $I(player) = {o1, o2}$ means
#    that only objects o_1 and o_2 have the property of being a player. For the
#    binary relation `plays_for`, the interpretation is a set of pairs:
#    `{(o1, o4), ...}`. This means the ... TRUE...
#
#    ... to check if STATEMENT is true, you look at the INTERPRETATION of saka
#    (o_1) and see if there is any object in the DOMAIN that o_1 is paired with in
#    the INTERPRETATION of `plays_for`. Since ... and ... the formula is true in
#    that specific L-structure.
#
#
# ---
