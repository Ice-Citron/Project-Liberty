# %% [markdown]
# # Slide 4: Knowledge Distillation

# %%
graph LR
    classDef teacher fill:#4285f4,stroke:#1a73e8,stroke-width:2px,color:#fff;
    classDef student fill:#34a853,stroke:#1e8e3e,stroke-width:2px,color:#fff;
    classDef data fill:#fbbc04,stroke:#f9ab00,stroke-width:2px,color:#000;
    classDef output fill:#ea4335,stroke:#c5221f,stroke-width:2px,color:#fff;

    A[Teacher Model<br/>e.g. OpenAI O1]:::teacher --> B[Generates<br/>Synthetic Data]:::data
    B --> C[Student Model<br/>e.g. DeepSeek R1]:::student
    C --> D[Matches Teacher<br/>at Fraction of Cost]:::output
    
    E[Billions of $$$<br/>Years of Training]:::teacher -.-> A
    F[Minimal Compute<br/>Months of Training]:::student -.-> C

# %% [markdown]
# # Slide 5: The FOSS Implication

# %%
timeline
    title FOSS Catching Up to Frontier
    section 2024
        GPT-4 Released : OpenAI leads by 6+ months
    section Jan 2025
        DeepSeek R1 : Gap closes to 2-3 months
        Distillation Controversy : OpenAI accuses theft
    section Dec 2025
        DeepSeek V3.2 : Gap now 1-2 months
        Surpasses GPT-5.1 : On several benchmarks

# %% [markdown]
# # Slide 6: Presentation Roadmap

# %%
graph LR
    classDef current fill:#4285f4,stroke:#1a73e8,stroke-width:2px,color:#fff;
    classDef future fill:#e8eaed,stroke:#9aa0a6,stroke-width:1px,color:#000;

    A[1. Ethical Analysis]:::future --> B[2. Acceleration<br/>Deadlock]:::future
    B --> C[3. Failure of<br/>Regulation]:::future
    C --> D[4. What Would<br/>We Do Differently?]:::future

# %% [markdown]
# # Slide 7: Transition to Ethics

# %%
graph TD
    classDef step fill:#4285f4,stroke:#1a73e8,stroke-width:2px,color:#fff;
    classDef question fill:#fff,stroke:#333,stroke-width:2px,color:#000;
    
    A[Ethical Decision Tree]:::step --> B{Step 1:<br/>Is it Legal?}:::question
    B --> C{Step 2:<br/>Does it violate<br/>Professional Duties?}:::question
    C --> D{Step 3:<br/>What produces the<br/>greatest good?}:::question
    D --> E[Final Assessment]:::step

# %% [markdown]
# # Slide 9: Legality Verdict

# %%
graph LR
    classDef grey fill:#9aa0a6,stroke:#5f6368,stroke-width:3px,color:#fff;
    
    A[LEGAL GREY AREA]:::grey

# %% [markdown]
# # Slide 11: ACM 1.5 - Respect for Others' Work

# %%
graph LR
    classDef invest fill:#4285f4,stroke:#1a73e8,stroke-width:2px,color:#fff;
    classDef extract fill:#ea4335,stroke:#c5221f,stroke-width:2px,color:#fff;
    classDef result fill:#fbbc04,stroke:#f9ab00,stroke-width:2px,color:#000;

    subgraph OpenAI Investment
        A[Billions of $$$]:::invest
        B[Thousands of Researchers]:::invest
        C[Expensive Compute<br/>Expenditure for Training]:::invest
        D[Massive Datasets]:::invest
    end
    
    A --> E[O1 / GPT-5.1]:::invest
    B --> E
    C --> E
    D --> E
    
    E --> F[Deepseek's Distillation<br/>Extracts Value]:::extract
    F --> G[DeepSeek R1<br/>Fraction of Cost]:::result

# %% [markdown]
# # SLIDE 12: ACM 1.2 — Avoid Harm

# %%
graph TD
    classDef release fill:#34a853,stroke:#1e8e3e,stroke-width:2px,color:#fff;
    classDef harm fill:#ea4335,stroke:#c5221f,stroke-width:2px,color:#fff;
    classDef actor fill:#fbbc04,stroke:#f9ab00,stroke-width:2px,color:#000;

    A[DeepSeek Releases<br/>Open Weights]:::release --> B[Anyone Can<br/>Download & Modify]:::release
    
    B --> C[Cybercriminals]:::actor
    B --> D[Rogue States<br/>e.g. North Korea]:::actor
    B --> E[Malicious Actors]:::actor
    
    C --> F[Sophisticated<br/>Attack Vectors]:::harm
    D --> G[State-Level<br/>AI Capabilities]:::harm
    E --> H[Biological/Chemical<br/>Applications]:::harm

# %% [markdown]
# # Slide 14: Deontology Verdict

# %%
graph TD
    classDef fail fill:#ea4335,stroke:#c5221f,stroke-width:2px,color:#fff;
    classDef code fill:#e8eaed,stroke:#9aa0a6,stroke-width:1px,color:#000;

    A[ETHICALLY PROBLEMATIC]:::fail
    
    B[ACM 1.5<br/>Respect Others' Work]:::code --> C[Failed]:::fail
    D[ACM 1.2<br/>Avoid Harm]:::code --> E[Failed]:::fail
    F[BCS Article 1<br/>Public Wellbeing]:::code --> G[Failed]:::fail

# %% [markdown]
# # Slide 15: Step 3 - Utilitarianism

# %%
graph LR
    classDef pro fill:#34a853,stroke:#1e8e3e,stroke-width:2px,color:#fff;
    classDef con fill:#ea4335,stroke:#c5221f,stroke-width:2px,color:#fff;
    classDef question fill:#fbbc04,stroke:#f9ab00,stroke-width:3px,color:#000;

    A{Greatest Good<br/>for Greatest Number?}:::question
    
    A --> B[FOSS Proponents:<br/>Distillation is GOOD]:::pro
    A --> C[Closed Source:<br/>Distillation is BAD]:::con

# %% [markdown]
# # Slide 16: FOSS Proponents - Distillation is Good

# %%
graph TD
    classDef monopoly fill:#ea4335,stroke:#c5221f,stroke-width:2px,color:#fff;
    classDef disrupt fill:#fbbc04,stroke:#f9ab00,stroke-width:2px,color:#000;
    classDef benefit fill:#34a853,stroke:#1e8e3e,stroke-width:2px,color:#fff;

    subgraph Before Distillation
        A[OpenAI, Google, Anthropic]:::monopoly --> B[Control Access]:::monopoly
        B --> C[Determine Pricing]:::monopoly
        C --> D[Shape Applications]:::monopoly
    end
    
    E[Distillation<br/>Disrupts Monopoly]:::disrupt
    
    subgraph After Distillation
        F[Student in Lagos]:::benefit
        G[Startup in Indonesia]:::benefit
        H[Researcher Anywhere]:::benefit
    end
    
    D --> E
    E --> F
    E --> G
    E --> H

# %% [markdown]
# # Slide 17 - Closed Source

# %%
graph TD
    classDef distill fill:#ea4335,stroke:#c5221f,stroke-width:2px,color:#fff;
    classDef harm fill:#ea4335,stroke:#c5221f,stroke-width:2px,color:#fff;
    classDef result fill:#5f6368,stroke:#3c4043,stroke-width:2px,color:#fff;

    A[Competitors Can<br/>Simply Distill]:::distill
    
    A --> B[Why Invest Billions<br/>in Training?]:::harm
    A --> C[Open Weights to<br/>Dangerous Actors]:::harm
    
    B --> D[Incentive Structure<br/>Collapses]:::result
    B --> E[Innovation<br/>Decelerates]:::result
    
    C --> F[Terrorist<br/>Organisations]:::result
    C --> G[Authoritarian<br/>Regimes]:::result
    C --> H[Malicious<br/>Individuals]:::result
    
    D --> I[Frontier<br/>Stagnates]:::result
    E --> I
    F --> J[No Safety<br/>Controls]:::result
    G --> J
    H --> J

# %% [markdown]
# # Slide 18 - Our Assessment

# %%
graph LR
    classDef pro fill:#34a853,stroke:#1e8e3e,stroke-width:2px,color:#fff;
    classDef con fill:#ea4335,stroke:#c5221f,stroke-width:2px,color:#fff;
    classDef tension fill:#fbbc04,stroke:#f9ab00,stroke-width:3px,color:#000;

    A[FOSS Movement]:::pro --> C{THE<br/>PROBLEM}:::tension
    B[Closed Source]:::con --> C
    
    C --> D[Both positions<br/>are partially correct]:::tension

# %% [markdown]
# # Slide 19: Stakeholder Analysis

# %%
---
config:
  theme: dark
---
graph TD
    classDef primary fill:#ea4335,stroke:#c5221f,stroke-width:2px,color:#fff;
    classDef secondary fill:#fbbc04,stroke:#f9ab00,stroke-width:2px,color:#000;
    classDef partial fill:#4285f4,stroke:#1a73e8,stroke-width:2px,color:#fff;
    classDef systemic fill:#5f6368,stroke:#3c4043,stroke-width:2px,color:#fff;

    A[DeepSeek]:::primary --> E[Primary Responsibility<br/>Violated ACM 1.5, enabled harm.]
    
    B[OpenAI]:::secondary --> F[Within Ethical Bounds.<br/>But contributes to <br/>consolidation of monopolies.]
    
    C[FOSS Community]:::partial --> G[Partial Responsibility<br/>Many act in good faith<br/>But their work allows WMDs to be proliferated to Bad actors]
    
    D[Political Powers<br/>US & China]:::systemic --> H[Failed to Establish<br/>International Frameworks]

# %% [markdown]
# # Slide 23: The Core Problem - No Moat

# %%
---
config:
  theme: redux-dark
---
graph LR
    classDef frontier fill:#4285f4,stroke:#1a73e8,stroke-width:2px,color:#fff;
    classDef foss fill:#34a853,stroke:#1e8e3e,stroke-width:2px,color:#fff;
    classDef time fill:#fbbc04,stroke:#f9ab00,stroke-width:2px,color:#000;
    classDef nomoat fill:#ea4335,stroke:#c5221f,stroke-width:3px,color:#fff;

    A[OpenAI Trains<br/>New Frontier Model]:::frontier --> B[Papers Published<br/>Techniques Known]:::time
    B --> C[FOSS Replicates<br/>Within Months]:::foss
    C --> D[NO DURABLE<br/>COMPETITIVE MOAT]:::nomoat
    D --> A

# %% [markdown]
# # SLIDE 24: The Acceleration Deadlock — Overview

# %%
graph LR
    classDef plain fill:#fff,stroke:#333,stroke-width:1px,color:#000;
    classDef start fill:#e1f5fe,stroke:#01579b,stroke-width:2px,color:#000;
    classDef endnode fill:#c62828,stroke:#b71c1c,stroke-width:4px,color:#fff;
    classDef decision fill:#fff9c4,stroke:#fbc02d,stroke-width:2px,color:#000;
    classDef converge fill:#ffe0b2,stroke:#e65100,stroke-width:2px,color:#000;

    Start[DeepSeek<br/>Distillation]:::start --> Implication(Implication of<br/>FOSS Movement):::plain
    Implication --> NoMoat["Distilled Models =<br/>NO MOAT<br/>(FOSS 1-2 months behind)"]:::plain
    
    NoMoat --> Split{AI Bubble<br/>Bursts?}:::decision

    Split -- NO --> CapEx[Massive CapEx Race<br/>Fuelled by Debt]:::plain
    CapEx --> Justify[Frontier Labs MUST<br/>Accelerate to<br/>Justify ROI]:::plain
    Justify --> CorpRisk[Corps Cut Corners<br/>to Maintain Lead]:::plain

    Split -- YES --> Crash["Economic Crash<br/>& Job Losses"]:::plain
    Crash --> CheapCompute["Compute Becomes<br/>Cheap & Abundant"]:::plain
    CheapCompute --> FOSSRisk[Unregulated Actors<br/>Run Wild with AI]:::plain

    CorpRisk --> Deadlock(The Acceleration<br/>Deadlock):::converge
    FOSSRisk --> Deadlock
    
    Deadlock --> Final((UNSAFE AGI<br/>Pandora's Box<br/>Opened)):::endnode

# %% [markdown]
# # SLIDE 25: Scenario A — Bubble Does NOT Burst

# %%
graph TD
    classDef invest fill:#4285f4,stroke:#1a73e8,stroke-width:2px,color:#fff;
    classDef pressure fill:#fbbc04,stroke:#f9ab00,stroke-width:2px,color:#000;
    classDef corner fill:#ea4335,stroke:#c5221f,stroke-width:2px,color:#fff;

    A[Investors Continue<br/>Funding the Race]:::invest --> B[Frontier Labs Must<br/>Accelerate to Justify ROI]:::pressure
    B --> C[Massive Debt<br/>Promised Returns]:::pressure
    C --> D[Maintaining Lead<br/>Increasingly Difficult]:::pressure
    D --> E[Corporations<br/>Cut Corners]:::corner
    
    E --> F[Safety Testing<br/>Abbreviated]:::corner
    E --> G[Alignment Research<br/>Deprioritised]:::corner
    E --> H[Models Released<br/>More Rapidly]:::corner

# %% [markdown]
# # Slide 27: Scenario B -- Bubble DOES Burst

# %%
graph TD
    classDef crash fill:#ea4335,stroke:#c5221f,stroke-width:2px,color:#fff;
    classDef insight fill:#fbbc04,stroke:#f9ab00,stroke-width:2px,color:#000;
    classDef danger fill:#5f6368,stroke:#3c4043,stroke-width:2px,color:#fff;

    A[AI Bubble<br/>Collapses]:::crash --> B[Economic Crash<br/>Job Losses]:::crash
    B --> C[Broader<br/>Recession]:::crash
    
    C --> D[BUT: Compute Becomes<br/>Cheap & Abundant]:::insight
    D --> E[Data Centres<br/>Still Exist]:::insight
    E --> F[GPUs Still<br/>Function]:::insight
    
    F --> G[Actors Who Couldn't<br/>Afford Training NOW CAN]:::danger
    
    G --> H[Unregulated<br/>Individuals]:::danger
    G --> I[Criminal<br/>Organisations]:::danger
    G --> J[Rogue<br/>States]:::danger

# %% [markdown]
# # Slide 28: Convergence -- Pandora's Box

# %%
graph TD
    classDef pathA fill:#4285f4,stroke:#1a73e8,stroke-width:2px,color:#fff;
    classDef pathB fill:#ea4335,stroke:#c5221f,stroke-width:2px,color:#fff;
    classDef converge fill:#5f6368,stroke:#3c4043,stroke-width:3px,color:#fff;

    A[Scenario A:<br/>Bubble Doesn't Burst]:::pathA --> C[SAME OUTCOME]:::converge
    B[Scenario B:<br/>Bubble Bursts]:::pathB --> C
    
    C --> D[Dangerous Capabilities<br/>Widely & Uncontrollably<br/>Available]:::converge
    D --> E[UNSAFE AGI]:::converge

# %% [markdown]
# # Slide 30: The EU AI Act

# %%
graph LR
    classDef paper fill:#34a853,stroke:#1e8e3e,stroke-width:2px,color:#fff;
    classDef reality fill:#ea4335,stroke:#c5221f,stroke-width:2px,color:#fff;

    subgraph On Paper
        A[Comprehensive<br/>Transparency Requirements]:::paper
        B[Mandatory<br/>Safety Testing]:::paper
        C[Human<br/>Oversight]:::paper
    end
    
    subgraph In Reality
        D[Researchers Depart<br/>for the US]:::reality
        E[Startups Relocate<br/>to SF & London]:::reality
        F[EU AI Firms<br/>Fall Behind]:::reality
        G[VC Funding<br/>Collapses]:::reality
    end
    
    A --> D
    B --> E
    C --> F

# %% [markdown]
# # Slide 32: The Fundamental Problem

# %%
graph TD
    classDef eu fill:#4285f4,stroke:#1a73e8,stroke-width:2px,color:#fff;
    classDef us fill:#ea4335,stroke:#c5221f,stroke-width:2px,color:#fff;
    classDef china fill:#fbbc04,stroke:#f9ab00,stroke-width:2px,color:#000;
    classDef limit fill:#9aa0a6,stroke:#5f6368,stroke-width:2px,color:#fff;

    A[EU AI Act]:::eu --> B[Can Regulate<br/>EU Researchers]:::eu
    
    A -.-> C[Cannot Compel<br/>OpenAI / Anthropic / DeepMind<br/>in San Francisco]:::limit
    A -.-> D[Cannot Compel<br/>DeepSeek<br/>in Hangzhou]:::limit
    
    B --> E[Only Handicaps<br/>Own Researchers]:::limit
    
    F[United States]:::us --> G[No Incentive<br/>to Slow Down]:::us
    H[China]:::china --> I[No Incentive<br/>to Slow Down]:::china
    
    G --> J[AI = Military Supremacy<br/>Economic Dominance<br/>Future of Warfare]
    I --> J

# %% [markdown]
# # Slide 33: The Prisoner's Dilemma

# %%
graph TD
    classDef regulate fill:#34a853,stroke:#1e8e3e,stroke-width:2px,color:#fff;
    classDef accelerate fill:#ea4335,stroke:#c5221f,stroke-width:2px,color:#fff;
    classDef outcome fill:#fbbc04,stroke:#f9ab00,stroke-width:2px,color:#000;
    classDef bad fill:#5f6368,stroke:#3c4043,stroke-width:2px,color:#fff;

    A{Nation's Choice}
    
    A --> B[Regulate<br/>Aggressively]:::regulate
    A --> C[Do Not<br/>Regulate]:::accelerate
    
    B --> D[Falls Behind<br/>Economically & Militarily]:::bad
    C --> E[Accelerates<br/>the Race]:::bad
    
    D --> F[LOSE]:::bad
    E --> G[Everyone<br/>Accelerates]:::bad
    G --> H[UNSAFE AGI]:::bad

# %% [markdown]
# # Slide 34: Why International Coalition Won't Work

# %%
graph LR
    classDef nuclear fill:#4285f4,stroke:#1a73e8,stroke-width:2px,color:#fff;
    classDef ai fill:#ea4335,stroke:#c5221f,stroke-width:2px,color:#fff;
    classDef check fill:#34a853,stroke:#1e8e3e,stroke-width:2px,color:#fff;
    classDef cross fill:#ea4335,stroke:#c5221f,stroke-width:2px,color:#fff;

    subgraph Nuclear Non-Proliferation Works
        A[Requires Rare<br/>Materials]:::nuclear
        B[Requires Massive<br/>Infrastructure]:::nuclear
        C[Detectable<br/>from Space]:::nuclear
    end
    
    subgraph AI Non-Proliferation Cannot Work
        D[Requires Only<br/>Code]:::ai
        E[Requires Only<br/>Compute]:::ai
        F[Impossible<br/>to Monitor]:::ai
    end

# %% [markdown]
# # Slide 36: Decision Tree Walkthrough

# %%
---
config:
  theme: redux-dark
---
graph LR
    classDef question fill:#fff9c4,stroke:#fbc02d,stroke-width:2px,color:#000;
    classDef yes fill:#34a853,stroke:#1e8e3e,stroke-width:2px,color:#fff;
    classDef no fill:#ea4335,stroke:#c5221f,stroke-width:2px,color:#fff;
    classDef action fill:#4285f4,stroke:#1a73e8,stroke-width:2px,color:#fff;

    A{Step 1:<br/>Systemic issue that<br/>individual ethics<br/>cannot resolve?}:::question
    A -- YES --> B[Acceleration Deadlock<br/>proves this]:::yes
    
    B --> C{Step 2:<br/>Can traditional<br/>regulation resolve it?}:::question
    C -- NO --> D[EU failure<br/>demonstrates this]:::no
    
    D --> E{Step 3:<br/>Is international<br/>coordination feasible?}:::question
    E -- NO --> F[Geopolitical incentives<br/>prevent this]:::no
    
    F --> G[Step 4:<br/>Pursue Alternative<br/>Approaches]:::action
    G --> H[Work WITHIN the<br/>existing dynamic]:::action

# %% [markdown]
# # Slide 37: Recommendation 1 -- Technical Governance

# %%
graph LR
    classDef pol fill:#ea4335,stroke:#c5221f,stroke-width:2px,color:#fff;
    classDef tech fill:#4285f4,stroke:#1a73e8,stroke-width:2px,color:#fff;
    classDef outcome fill:#34a853,stroke:#1e8e3e,stroke-width:2px,color:#fff;
    classDef bad fill:#9aa0a6,stroke:#5f6368,stroke-width:2px,color:#fff;

    subgraph Current Situation
        A[Policymakers<br/>No Technical Understanding]:::pol --> B[Ineffective or<br/>Counterproductive Rules]:::bad
    end
    
    subgraph What We Recommend
        C[Political Scientists]:::pol --> E[Democratic Systems<br/>Informed by<br/>Technical Reality]:::outcome
        D[Technical Experts]:::tech --> E
    end

# %% [markdown]
# # Slide 38: Recommendation 2 -- Upskilling & Education

# %%
graph TD
    classDef empowered fill:#34a853,stroke:#1e8e3e,stroke-width:2px,color:#fff;
    classDef left fill:#ea4335,stroke:#c5221f,stroke-width:2px,color:#fff;
    classDef action fill:#4285f4,stroke:#1a73e8,stroke-width:2px,color:#fff;
    classDef warning fill:#fbbc04,stroke:#f9ab00,stroke-width:2px,color:#000;

    A[AI-Empowered<br/>Workers]:::empowered
    B[Workers Without<br/>AI Skills]:::left
    
    A --> C[Gap Widens<br/>Dramatically]:::warning
    B --> C
    
    C --> D[Countries That<br/>Fail to Upskill]:::left
    D --> E[Permanent Economic<br/>Subordination]:::left
    
    F[Solution:<br/>Massive Education<br/>Investment]:::action --> G[Work ALONGSIDE AI<br/>Not Compete With It]:::empowered

# %% [markdown]
# # SLIDE 39: Recommendation 3 — Economic Safety Nets

# %%
graph LR
    classDef gains fill:#34a853,stroke:#1e8e3e,stroke-width:2px,color:#fff;
    classDef concentrated fill:#ea4335,stroke:#c5221f,stroke-width:2px,color:#fff;
    classDef distributed fill:#4285f4,stroke:#1a73e8,stroke-width:2px,color:#fff;

    A[Enormous AI<br/>Productivity Gains]:::gains
    
    A --> B[Concentrated<br/>in Few Hands]:::concentrated
    A --> C[Distributed<br/>Across Society]:::distributed
    
    B --> D[Inequality<br/>Explodes]:::concentrated
    C --> E[Shared<br/>Prosperity]:::distributed
    
    F[UBI]:::distributed --> C

# %% [markdown]
# # Slide 40: Recommendation 4 -- Energy & Climate

# %%
graph TD
    classDef current fill:#ea4335,stroke:#c5221f,stroke-width:2px,color:#fff;
    classDef solution fill:#34a853,stroke:#1e8e3e,stroke-width:2px,color:#fff;
    classDef warning fill:#fbbc04,stroke:#f9ab00,stroke-width:2px,color:#000;

    A[Current AI<br/>Infrastructure]:::current --> B[Accelerating Fossil<br/>Fuel Extraction]:::current
    A --> C[Straining<br/>Water Supplies]:::current
    
    B --> D[Climate Change<br/>Accelerates]:::warning
    C --> D
    
    D --> E[Trading One<br/>Existential Risk<br/>for Another]:::warning
    
    F[Solution:<br/>Aggressive Scaling of<br/>Renewable Energy]:::solution
    
    F --> G[Nuclear]:::solution
    F --> H[Solar]:::solution
    F --> I[Wind]:::solution

# %% [markdown]
# # Bubble Scenario

# %%
---
config:
  theme: dark
---
graph LR
    %% STYLE DEFINITIONS
    classDef plain fill:#ffffff,stroke:#333,stroke-width:1px,font-family:Helvetica,color:#000;
    classDef trigger fill:#e3f2fd,stroke:#1565c0,stroke-width:2px,color:#000;
    classDef corporate fill:#e8f5e9,stroke:#2e7d32,stroke-width:2px,color:#000;
    classDef anarchic fill:#ffebee,stroke:#c62828,stroke-width:2px,color:#000;
    classDef deadlock fill:#fff9c4,stroke:#fbc02d,stroke-width:2px,stroke-dasharray: 5 5,color:#000;
    classDef doom fill:#263238,stroke:#000,stroke-width:4px,color:#fff;

    %% SECTION 1: THE CATALYST (Left)
    Start["<b>DeepSeek Distillation</b><br/>(The Catalyst)"]:::trigger --> Reality("<b>FOSS Implication</b><br/>SOTA Intelligence is<br/>now a commodity"):::trigger
    Reality --> Lag["<b>The 'No Moat' Reality</b><br/>Open Source is only<br/>1-2 months behind"]:::plain

    %% SECTION 2: THE FORK (Middle)
    Lag --> Split{"<b>Does the<br/>Bubble Burst?</b>"}:::deadlock

    %% TOP PATH: THE CORPORATE TRAP (Bubble Survives)
    Split -- "<b>NO</b>" --> CapEx["<b>Massive CapEx Race</b><br/>Funded by Debt<br/>(Magnificent 7 & Nvidia)"]:::corporate
    CapEx --> ROI["<b>Must Justify Valuation</b><br/>Labs forced to<br/>release early"]:::corporate
    ROI --> CorpRisk["<b>Safety Corner-Cutting</b><br/>'Code Red' to maintain<br/>dominance over FOSS"]:::corporate

    %% BOTTOM PATH: THE RESEARCHER REVOLUTION (Bubble Bursts)
    Split -- "<b>YES</b>" --> Crash["<b>Economic Crash</b><br/>Data Centers Liquidated<br/>Funding Dries Up"]:::anarchic
    Crash --> Hardware["<b>Compute Flood</b><br/>H100s/Inference become<br/>cheap & accessible"]:::anarchic
    Hardware --> Students["<b>Empowered Researchers</b><br/>(CS Students / You & Me)<br/>can train Frontier Models"]:::anarchic
    Students --> DormRoom["<b>'Decentralised' Acceleration</b><br/>Unregulated Experiments<br/>& Uncensored Fine-Tuning"]:::anarchic

    %% SECTION 3: THE CONVERGENCE (Right)
    CorpRisk --> Deadlock("<b>The Acceleration<br/>Deadlock</b>"):::deadlock
    DormRoom --> Deadlock
    
    Deadlock --> Final(("<b>UNSAFE AGI</b><br/>Pandora's Box<br/>Opened")):::doom


graph LR
    classDef teacher fill:#4285f4,stroke:#1a73e8,stroke-width:2px,color:#fff;
    classDef student fill:#34a853,stroke:#1e8e3e,stroke-width:2px,color:#fff;
    classDef data fill:#fbbc04,stroke:#f9ab00,stroke-width:2px,color:#000;
    classDef output fill:#ea4335,stroke:#c5221f,stroke-width:2px,color:#fff;

    A[Teacher Model<br/>e.g. OpenAI O1]:::teacher --> B[Generates<br/>Synthetic Data]:::data
    B --> C[Student Model<br/>e.g. DeepSeek R1]:::student
    C --> D[Matches Teacher<br/>at Fraction of Cost]:::output
    
    E[Billions of $$$<br/>Years of Training]:::teacher -.-> A
    F[Minimal Compute<br/>Months of Training]:::student -.-> C
