# %% [markdown]
# # Bubble Scenario

# %%
graph LR
    %% STYLE DEFINITIONS
    classDef plain fill:#ffffff,stroke:#333,stroke-width:1px,font-family:Helvetica,color:#000;
    classDef trigger fill:#e3f2fd,stroke:#1565c0,stroke-width:2px,color:#000;
    classDef corporate fill:#e8f5e9,stroke:#2e7d32,stroke-width:2px,color:#000;
    classDef anarchic fill:#ffebee,stroke:#c62828,stroke-width:2px,color:#000;
    classDef deadlock fill:#fff9c4,stroke:#fbc02d,stroke-width:2px,stroke-dasharray: 5 5,color:#000;
    classDef doom fill:#263238,stroke:#000,stroke-width:4px,color:#fff;

    %% SECTION 1: THE CATALYST (Left)
    Start["<b>DeepSeek Distillation</b><br/>(The Catalyst)"]:::trigger --> Reality("<b>FOSS Implication</b><br/>SOTA Intelligence is<br/>now a commodity"):::trigger
    Reality --> Lag["<b>The 'No Moat' Reality</b><br/>Open Source is only<br/>1-2 months behind"]:::plain

    %% SECTION 2: THE FORK (Middle)
    Lag --> Split{"<b>Does the<br/>Bubble Burst?</b>"}:::deadlock

    %% TOP PATH: THE CORPORATE TRAP (Bubble Survives)
    Split -- "<b>NO</b>" --> CapEx["<b>Massive CapEx Race</b><br/>Funded by Debt<br/>(Magnificent 7 & Nvidia)"]:::corporate
    CapEx --> ROI["<b>Must Justify Valuation</b><br/>Labs forced to<br/>release early"]:::corporate
    ROI --> CorpRisk["<b>Safety Corner-Cutting</b><br/>'Code Red' to maintain<br/>dominance over FOSS"]:::corporate

    %% BOTTOM PATH: THE RESEARCHER REVOLUTION (Bubble Bursts)
    Split -- "<b>YES</b>" --> Crash["<b>Economic Crash</b><br/>Data Centers Liquidated<br/>Funding Dries Up"]:::anarchic
    Crash --> Hardware["<b>Compute Flood</b><br/>H100s/Inference become<br/>cheap & accessible"]:::anarchic
    Hardware --> Students["<b>Empowered Researchers</b><br/>(CS Students / You & Me)<br/>can train Frontier Models"]:::anarchic
    Students --> DormRoom["<b>'Decentralised' Acceleration</b><br/>Unregulated Experiments<br/>& Uncensored Fine-Tuning"]:::anarchic

    %% SECTION 3: THE CONVERGENCE (Right)
    CorpRisk --> Deadlock("<b>The Acceleration<br/>Deadlock</b>"):::deadlock
    DormRoom --> Deadlock
    
    Deadlock --> Final(("<b>UNSAFE AGI</b><br/>Pandora's Box<br/>Opened")):::doom


graph LR
    classDef teacher fill:#4285f4,stroke:#1a73e8,stroke-width:2px,color:#fff;
    classDef student fill:#34a853,stroke:#1e8e3e,stroke-width:2px,color:#fff;
    classDef data fill:#fbbc04,stroke:#f9ab00,stroke-width:2px,color:#000;
    classDef output fill:#ea4335,stroke:#c5221f,stroke-width:2px,color:#fff;

    A[Teacher Model<br/>e.g. OpenAI O1]:::teacher --> B[Generates<br/>Synthetic Data]:::data
    B --> C[Student Model<br/>e.g. DeepSeek R1]:::student
    C --> D[Matches Teacher<br/>at Fraction of Cost]:::output
    
    E[Billions of $$$<br/>Years of Training]:::teacher -.-> A
    F[Minimal Compute<br/>Months of Training]:::student -.-> C
