# %% [markdown]
# okay but why is this called quotient? or ig it kinda makes sense because it divides down the number of buckets left compared to original? even tho how it divides things isn't perfect every time?
#
# ---
#    Yes, that is basically the right intuition, but with one important correction:
#
#    "Quotient" here means more like "divide out by a notion of sameness" than
#    "divide evenly into equal-sized pieces."
#
#    So when you form `A / R`, you are doing two things:
#    1. splitting `A` into equivalence classes
#    2. then treating each whole class as one single new object
#
#    That is why it feels like a kind of division:
#    - the original set had lots of separate elements
#    - after quotiening, elements that count as "the same under `R`" gets
#      collapsed together
#    - what remains is the set of buckets
#
#    So `A/R` is the result of "modding out by `R`" or "identifying things that
#    `R` says are equivalent."
#
#    The reason it is not about perfect equal division is:
#       - equivalence classes do not have to all be the same size
#       - some may be singleton classes
#       - some may be larger
#       - in infinite examples, the class sizes can vary wildly
#
#    So the word "quotient" is not about fairness or equal splitting. It is about
#    removing distinctions.
#
#    A good mental model is:#
#       - `A` = the original world
#       - `R` = the rule for when two things should be treated as the same
#       - `A/R` = the compressed world after those identifications
#
#    ...
#
#    This is very quotient-like: lots of information is being collapsed away.
#
#    So the cleanest sentence is:
#       A quotient set is what you get when you divide out a set by an equivalence
#       relation, meaning you replace each whole equivalence class by a single
#       new object.

# %% [markdown]
# ---

# %% [markdown]
# -- A quotient set, denoted $S / ~$ (or $S / R$), is the set of all equivalence
#    classes of a set $S$ generated by an equivalence relation $~$. It acts as a
#    way to "divide" a set by grouping equivalent elements together, effectively
#    forming a partition of the original set where each class is treated as a
#    single element.
#
# KEY CONCEPTS
#    - DEFINITION: Given a set $SS$ and an equivalence relation $~$, the quotient
#      set is the set of subsets $S / ~ = {[a] : a \in S}$, where
#      $[a] = {b \in S | b ~ a}$ represents the equivalence class of $a$.
#    - PARTITION: The quotient set defines a partition of the original set $S$,
#      meaning the union of all equivalence classes is $S$, and no two distinct
#      classes overlap.
#    - PARTITION DUALITY: Every equivalence relation produces a quotient set
#      (partition), and conversely, any partition of a set induces an equivalence
#      relation whose quotient set is the original partition.

# %% [markdown]
# ---

# %% [markdown]
#    ...
#
#    2. EQUIVALENCE CLASSES
#       When an equivalence relation $R$ is applied to a set $A$, it groups the
#       elements into subseets. The subset of all eleements related to a specific
#       element $a$ is called the EQUVALENCE CLASS of $a$, denoted by $[a]_R$s or
#       simply $[a]$.
#
#       - FORMAL DEFINITION: $[a] = {x \in A | x ~ a}$
#       - THE OVERLAP THEOREM: For any two elements, $a, b \in A$, their
#         equivalence classes $[a]$ and $b$ are either COMPLETELY IDENTICAL
#         (if $a R b$) or COMPLETELY DISJOINT (if $\neg (a R b)$). They can never
#         partially overlap.
#       - REPRESENTATIVES: Any elements inside an equivalence class can be used to
#         name the class. If $[a] = {a, b, c}$, then $[a] = [b] = [c]$
#
# COMPLETELY IDENTICAL
# COMPLETELY DISJOINT
#
#
#    3. PARTITIONS
#       A PARTITION of a set $A$ is a collection of non-empty subsets of $A$ that
#       strictly divides the entire set.
#
#       To be a valid partition, a collection of subsets $P = {S_1, S_2, \dots}$
#       must satisfy two rules:
#
#       1. EXHAUSTIVE (Union is $A$): Every element in $A$ must belong to at least
#          one subset. ($\bigcup S_i = A$rsdrr)
#       ...
#
#
#    THE FUNDAMENTAL THEOREM OF EQUIVALENCE RELATIONS:
#       There is a perfect, two-way mathematical bridge between equivalence
#       relations and partitions.
#       - Every equivalence relation on a set $A$ naturally produces a unique
#         partition of $A$ (the set of all its distinct equivalence classes).
#       - Conversely, every partition of a set $A$ implicitly defines an
#         equivalence relation (where $x R y$ if they are in the same subset).

# %% [markdown]
# -- The statement that EVERY CLASS HAS

# %% [markdown]
# TO DO LIST FOR TOMMOROW:
#
#    - CLAUDE QUESTIONS
#          Q1. Let A = {1,2,3,4,5,6} and x ~ y ⟺ x + y is even.

# %% [markdown]
# ---

# %% [markdown]
#    This lab is buil to make the order words stop blurring together. Pre-order
#    means "reflexive + transitive". Partial order "anti-symmetry + reflexive +
#    transitive". Strict partial order "anti-symmetric + irreflexive + transitive"
#    . Total order "aRb or bRa (every pair becomes comparable)". Strict total order
#    means total order (every pair becomes comparable) ++ irreflexive (diagonals are incomparables)
#    . The matrix shows the raw relation, the graph shows the arrows, and the Hasse
#    view strips away the redundant arrows so the actual structure shows up.
#
#
# ### Why <= and < fit together so neatly
#    From a partial order <=, define the strict version b
#    a < b iff a <= b and a != b. From a strict partial order <, recover the
#    reflexive version by  a <= b iff a < b or a = b.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# -- Okay... this stuff here about why `<` is normally referred to as a
#    `strict partial order` instead of a `strict total order`, when in reality its
#    both makes sense!
#
#    This is because partial order is more general than total order... so a lot
#    of proofs are built on strict-poset instead of strict-toset... as this
#    enables proofs to quality for broader and more general categories!
#
#    (because total order is nicher... due to its requirements of `a<b or b<a`...
#    when strict-poset... in reality... is both!)

# %% [markdown]
# ---

# %% [markdown]
# ## Rock Paper Scissors (Irreflexive, but not an order)
#
# ### Real-world translation
#    This is cyclic dominance. It looks directional, but it is not an order
#    because it loops around rather than stacking.
#
# ### What the matrix is telling you
#    - The diagonal is dark, so irreflexivity survives.
#    - Rock beats Scissors and Scissors beats Paper, but Rock does not beat Paper,
#      so transivity fails.
#    - The cycle means there is no Hasse diagram here.
#    - Anti-symmetry holds vacuously because no distinct pair points both ways.
#
# ### Structure takeaway
#    - It is a good reminder that `has arrows` is not enough. Orders need
#      transitivity, and cycles destory the staircase feeling.
#
#
# ...
#
#
# ## Subset Inclusion (A partial order, not total)
#
# ### What the matrix is telling you
#    - The diagonal is on, so every set includes itself.
#    - {a} and {b} are both missing in each other's cells, so totality fails.
#    - There are no two-way arrows between distinct nodes, so anti-symmetry
#      survives.
#    - The Hasse diagram becomes a diamond.
#
# ### Structure takeaway
#    - This is the standard picture of a partial order: reflexive, transitive,
#      anti-symmetric, but some pairs are incomparable.
#
#
# ...
#
#
# ## Number line <= (A total order)
#
# ### Real-world translation
#    This is queue position, time order, page orer, or any single-axis ranking
#    where every pair is comparable.
#
# ### What the matrix is telling you
#    - Everything on and above the diagonal is lit. (transitivity + fulfils totality)
#    - Every distinct pair is comparable in exactly one direction.
#    - Reflexivity survives because the diagonal is on.
#    - The Hasse diagram only keeps the nearest-neighbour edges.
#
# ### Structure takeaway
#    A total order is just a partial order with no incomparability left. The
#    Hasse diagram is a straight-chain.
#
#
# ---
# ## Proper Subset (A strict partial order)
#
# ### Real-world translation
#    Think of one capability bundle being strictly smaller than another. Equality
#    ...
#
#    ...
#    - There ae still incomparable pairs, so this is not total.
#    ...
#    - Adding the identity relation back would recover the partial order version.
#
#
# ## Divisibility Pocket (Paper-style partial order with maxima and minima)
#
# ### Real-world translation
#    Think of factor containment: smaller numbers sit below the numbers they build
#
# ### What the matrix is telling you
#    - The diagonal is on because every number divides itself.
#    - 2 and 5 are incomparable, so the order is not total.
#    - There are no two-way arrows between distinct numbers, so anti-symmetry
#      survives.
#    - The Hasse view is where maximal and minimal elements become obvious.

# %% [markdown]
#    A partial order <A, <=A> is WELL FOUNDED when it has no INFINITE DECREASING
#    CHAIN OF ELEMENTS: that is, for EVERY infinite sequence a_1, a_2, a_3, ...
#    of elements in $A$ with
#
#       a_1 >= a_2 >= a_3 >= ...
#
#    there exists m \in \mathbf{N} s.t. a_n = a_m for every n >= m.
#
#    A well-founded order need not be total, like the subset relation on the set
#    of finite subsets of \mathbf{N}.

# %% [markdown]
# ## MINIMAL / LEAST / MAXIMAL / GREATEST
#
# ### How to read the words
#    Minimal means nothing strictly below it. Least means below everything.
#    Maximal means nothing stricly above it. Greatest means above everything. In
#    a Hasse diagram,

# %% [markdown]
# # EXTERNAL ELEMENTS ATLAS
#    The key distinction is global versus local. A least element sits below
#    everything. A minimal element merely has nothing strictly below it. Same on
#    the top side: greatest is global, maximal is local. In finite non-empty
#    posets you always get at least one minimal and one maximal element. The weird
#    cases only show up once infinity enters.
#
#
# ---
# 2 | 4 true // 2 divides 4
#
# ---
#
# ### Lecture intuition
#    A poset is well-founded when there is no endless strict countdown. If every
#    descent makes some natural-number measure smaller, the order is usually
#    well-founded. This is why finite posets and many "size-decreasing"
#    constructions behave nicely.
