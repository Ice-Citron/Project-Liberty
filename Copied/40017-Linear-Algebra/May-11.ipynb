# %% [markdown]
# 1. Orthoganility (The "No Overlap" Rule)
#    - The Math: $u \cdot v = 0$
#    - HOW IT WORKS: ... the mathematical test for a perfect 90-deg angle. If the
#      dot product is zero, the vectors share absolutely zero information. Moving
#      along u does not move you along v at all... completely independent...
#
# 2. Projection (The "Shadow" Formula)
#    - The Math...
#    - How it works: calculates exactly how much of vector y points in the
#      direction of vector u.
#      - The fraction ... is just a scalar... It calculates the "similarity" or
#        "overlap" between the vectors.
#      - The $u$ at the very end simply gives that scalar a physical direction
#        so it becomes a vector again.
#
# 3. Gram-Schmidt (The "Overlap Remover")
#                         <-- turns independent vectors into orthonormal vectors
#    ... snippet cut off! The full formula should...
#    - ...
#    - How it works... looks terrifying but read it carefully: it is literally
#      just taking a messy vector (v_k) and SUBTRACTING THE PROJECTIONS (shadows)
#      it casts on all the previosulu cleaned vectors...
#    - Once you chop off all the overlapping shadows, the only thing left over (w_k)
#      is the pure independent part of the vector sticking straight out at a
#      90 deg angle...
#
# 4. Cauchy-Schwarz (The "Speed Limit" of Vectors)
#    - ...
#    - How it works: This is the ultimate law of vector similarity. It states that
#      the "overlap" between two vectors (LHS) can NEVER be bigger than just
#      multiplying their raw lengths together (RHS).
#    - The Equality Rule: The only possible way to reach the absolute

# %% [markdown]
# FAME IS A GUN
