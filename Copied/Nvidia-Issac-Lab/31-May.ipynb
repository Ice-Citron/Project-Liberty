# %% [markdown]
# Google Search Query
#    - what is a jacobian matrix in robotics
#    - what is a neural network jacobean matrix in first derivative of loss functions

# %% [markdown]
# PRACTICE EXERCISES
#     https://gemini.google.com/app/8a58d991c80c3c0f

# %% [markdown]
# I’ll frame this as embodiment-conditioned robot foundation models: using URDF/CAD/kinematic structure to embed robot bodies, unify action/state spaces, and connect sparse cross-robot datasets.
#     https://chatgpt.com/c/6a1b0644-4104-83eb-8c72-eff8519e96eb

# %% [markdown]
# ---

# %% [markdown]
# THE ORCA Hand:
#    - https://srl.ethz.ch/orcahand.html
