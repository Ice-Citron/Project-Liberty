# %% [markdown]
# .venv/bin/python -c "import mujoco; p='assets/mujoco/rack_insert/rack_insert_scene.xml'; m=mujoco.MjModel.from_xml_path(p); print('OK', m.nbody, m.nsite, m.ngeom, m.njnt, m.nu)"
# .venv/bin/python -c "import mujoco; p='assets/mujoco/rack_insert/rack_insert_scene_eval.xml'; m=mujoco.MjModel.from_xml_path(p); print('OK', m.nbody, m.nsite, m.ngeom, m.njnt, m.nu)"

# %% [markdown]
# ---

# %% [markdown]
#    That line is a compiler flag that passes a file path straight from your
#    Makefile directly into your C code. The `-D` tells the compiler... to defne
#    a preprocessor macro named `MUJOCO_PLUGIN_DIR`. The `\"$(MUJOCO_DIR)/plugin\"`
#    part takes the value of your Makefile variable... and wraps it in escaped
#    quotes so it survives the build process as a valid, readable C string...
#    Ultimately, this means anywhere in your C source files where ...
#    the compiler will automatically swap it out for the actual system path to
#    MuJoCo's plugin folder, allowing your program to know exactly where to load
#    custom physics plugins from at runtime without ....

# %% [markdown]
# ---

# %% [markdown]
#    The `print_usage` function acts as your program's built-in instruction
#    manual for this command line. Its sole purpose is to show
