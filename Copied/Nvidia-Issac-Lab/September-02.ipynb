# %% [markdown]
# no i

# %% [markdown]
#    ... "wrench" does not refer to the hand tool; rather, it is a formal
#    physics and math term that comebines FORCES AND TORQUES into a single
#    6-D vector.
#
#    .... when you encounter the command or service `tare_wrench` (commonly
#    used with F/T sensors in robotic wrists or end-effecotrs), it means
#    ZEROING OUT OR CALIBRATING THE CURRENT FORCES acting on the sensor.
