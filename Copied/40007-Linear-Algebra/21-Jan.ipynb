# %%
                              /
                   __       //
                   -\= \=\ //
                 --=_\=---//=--
               -_==/  \/ //\/--
                ==/   /O   O\==--
   _ _ _ _     /_/    \  ]  /--
  /\ ( (- \    /       ] ] ]==-
 (\ _\_\_\-\__/     \  (,_,)--
(\_/                 \     \-
\/      /       (   ( \  ] /)
/      (         \   \_ \./ )
(       \         \      )  \
(       /\_ _ _ _ /---/ /\_  \
 \     / \     / ____/ /   \  \
  (   /   )   / /  /__ )   (  )
  (  )   / __/ '---`       / /
  \  /   \ \             _/ /
  ] ]     )_\_         /__\/
  /_\     ]___\
 (___)

# %% [markdown]
# This is the most critical concept for writing general solutions correctly, and
# it connects deeply to what a "basis" actually is.
#
# The reason we put a $1$ in the slot of the free variable (and $0$ in the others)
# is to guarantee that the direction vectors we find are INDEPENDENT (they don't
# point in the same direction).
#
# Here is the explanation from all three perspectives.
#
#
# ---
# 1. THE ALGEBRAIC "SANITY CHECK" (why it must be 1)
#
# Let's look at the vector $\text{x}$ itself. By definition, the vector is just a
# stack of its own components:
#
# $$\mathbf{x} = \begin{bmatrix} x_1 \\ x_2 \\ x_3 \\ x_4 \end{bmatrix}$$
#
#
# When we split the vector into parts that depend on $x_2$ and $x_4$, we are
# essentially asking: "HOW CAN WE REWRITE THIS COLUMN AS A SUM?"
#
# $$\begin{bmatrix} x_1 \\ \mathbf{x_2} \\ x_3 \\ \mathbf{x_4} \end{bmatrix} = \text{Constant Part} + x_2 \begin{bmatrix} ? \\ \mathbf{?} \\ ? \\ \mathbf{?} \end{bmatrix} + x_4 \begin{bmatrix} ? \\ \mathbf{?} \\ ? \\ \mathbf{?} \end{bmatrix}$$
#
#
# Focus ONLY on the second row (the $x_2$ row). The equation for that row is
# simply:
#
# $$x_2 = \text{something} + x_2(\mathbf{?}) + x_4(\mathbf{?})$$
#
#
# Since $x_2$ is a free variable, it doesn't depend on constants or $x_4$. It is
# equal to itself.
#
# $$x_2 = 0 + x_2(\mathbf{1}) + x_4(\mathbf{0})$$
#
#
# If you put anything other than $1$ in the $x_2$ vector's second slot, the math
# breaks.
# - If you put 5: You get $x_2 = 5x^2$ (False).
# - If you put 0: You get $x_2 = 0$ (False, because it's free).
#
# CONCLUSION: The "1" isn't a magic trick; it's the only way to satisfy the
# identity equation $x = x$.
#
#
#
# ------------|--<>
# 2. THE 3B1B GEOMETRIC INTUITION (BUILDING A GRID)
#
# Imagine the solution space is a 2D PLANE floating in a 4D room. To describe this
# plane to someone else, you need to give them two "arrows" (direction vectors)
# that lie on the plane, so they can walk anywhere on it.
#
# THE PROBLEM: If you choose two random arrows on the plane, you run the risk that
# they might point in the same direction (redundant) or be messy to work with.
#
#
# THE "1 AND 0" SOLUTION: You are essentially enforcing a specific, clean
# coordinate system (a grid) onto that floating plane.
# - VECTOR 1 ($x_2$ vector): You say, "Walk exactly 1 UNIT along the $x_2$ axis,
#   and 0 UNITS along the $x_4$ axis." The dependent variables $(x_1, x_3)$ will
#   adjust automatically to keep you on the plane.
#                                                                     <-- ah ok nvm... i can actually now kind of see this myself too... because like since the variables themselves are already free... you can't really double insert... fair enough!!
#
# - VECTOR 2 ($x_4$ VECTOR): You say, "Walk exactly 0 UNITS along the x_2 axis,
#   and 1 UNIT along the $x_4$ axis." Again, $x_1$ and $x_3$ adjust to compensate.
#
#
# WHY IS THIS GENIUS: By locking the movement to "1 step EAST, 0 steps NORTH" and
# "0 steps EAST, 1 step NORTH," you mathematically guarantee that your two
# direction vectors are LINEARLY INDEPENDENT (not parallel). They are
# perpendicular in the "free variable" dimensions.
#
#
#
#
# ------------|--<>
# 3. THE FUNCTION INTUITION (THJE MIXING BOARD)
#
# Think of the system as a sound mixing board.
# - THE OUTPUT: The final vector $\text{x}$.
# - THE INPUTS: Two slider knobs labelled "KNOB $x_2$" and "KNOB $x_4$".
# - THE DEPENDENT VARIABLES ($x_1$, $x_3$): Automated gears inside the machine
#   that turn automatically when you touch the knobs.

# %% [markdown]
# ---

# %% [markdown]
# wait so does this mean that... we can actually have a lot of variants for the constant variable? that is like... because all we need is just a point on the plane no?
# and tbf similarly... the direction vectors just need to be like scales of themselves???
#
# ---------|--<>
#
#
# ... 100% correct.
#
# The "General Solution" you write down is just ONE VALID DESCRIPTION of the
# solution set, not the only description.
#
#
#
# 1. THE CONSTANT VECTOR (THE STARTING POINT)
#
# YOUR INTUITION: "Because all we need is just a point on the plane no?"
# VERDICT: CORRECT.
#
# The algorithm (setting free variables to 0) gives you specific "anchor point" on
# the plane. But you could choose ANY other on that plane to be your anchor.
#
#
# GEOMETRIC ANALOGY:
# Imagine you are giving someone directions to a flat, infinite highway (the
# solution plane).
# - STANDARD ALGORITHM: "Start at the origin $(0, 0, 0)$, walk on the on-ramp at
#   $(1, 2, 0)$, then follow the road."
# - YOUR VARIANT: "Start at the gas station at $(10, 5, 1)$, then follow the road."
# - BOTH ARE VALID because both starting points are on the highway.
#
#
# ALGEBRAIC PROOF: If $x_p$ is a particular solution ($Ax_p = b$) aand $v$ is a
# direction vector in the null space ($Av = 0$), then $(x_p + v)$ is also a
# particular solution:
#
# $$A(x_p + v) = Ax_p + Av = b + 0 = b$$
#
#
# So yes, you can add any multiple of your direction vectors to your constant
# vectors, and it's still a valid starting point.

# %%
                                              ____________
                               --)-----------|____________|
                                             /        /
               -)------========            /  _____ /
                        \     \          /   /____/
                          \     \      /        /
                            \     \__/_________/__
                              \ _ _| ^--      || |
                   ________--------|_____________|\
    -  \-----------                               ||
 -     ============================ ______________ |
    - _____________________________|  |'      || |/
                               /   |_____________|
                             /     /  \         \
                           /     /      \      ___\
               -)---------========        \    \____\
THE FORCE, LUKE,                            \         \
USE THE FORCE!                                \_________\_
                              --)-------------|___________|

# %% [markdown]
# 2. THE DIRECTION VECTORS (THE MAP DIRECTIONS)
#
# YOUR INTUITION: "The direction vectors just need to be like scales of
# themselves???" \
# VERDICT: CORRECT (and even more FLEXIBLE).
#
# They don't just have to be scales (e.g., $2v$). They can be LINEAR COMBINATIONS
# of each other, as long as they span the same plane.                                 <-- beautiful!!! // column space!
#
#
# GEOMETRIC ANALOGY: You are standing on that infinite flat highway. You need to
# define "directions" so someone can walk anywhere on it.
# - STANDARD ALGORITHM (1s and 0s): "You can walk North (Vector 1) or East (Vector
#   2)."
# - YOUR VARIANT: "You can walk North-East (Vector A) or South-West (Vector B)."
#
# As long as your two vectors aren't parallel (linearly dependent... pointing the
# same way), they describe the exact same surface.
#
#
#
# -------|--<>
# 3. THE "EXAM TRAP" (Why we stick to 1s and 0s)
#
# If you are correct, why did the lecturer (and why do I) insist on the "1 in the
# slot" method?
#
#
# REASON 1: GUARANTEED INDEPENDENCE
# If you try to be creative and pick "Vector A" and "Vector B" yourself, you run
# the risk of accidentally picking two vectors that point in the same direction.
#
# - By using $(1, 0, ...)$ and $(0, 1, ...)$ the math GUARANTEES they are
#   independent. You can't mess it up.
#
#
# REASON 2: THE GRADING KEY
# This is the pragmatic Imperial Year 1 Tip:
# - The examiner has a marking scheme with ONE SPECIFIC ANSWER (the canonical form).
# - If you write a different (but valid) starting point and different (but valid)
#   direction vectors, the grader has to pause, do extra math to check if your
#   plane is the same as their plane.
# - DON'T MAKE THE GRADER DO MATH They might make a mistake and mark you wrong.
#
#
# SUMMARY
# - MATHEMATICAL REALITY: The solution is a geometric shape (line/plane). Any
#   point on it + any basis vectors spanning it = VALID GENERAL SOLUTION.
# - EXAM REALITY: Just use the 0s and 1s method. It's the "Default Settings" for
#   Linear Algebra,

# %% [markdown]
# huh... so in the case that we get 2 free variables for a augmented matrix of A to B...
#
# does this mean that conducting this matmul operations results in us getting a plane as a result? but what does this plane mean tho... does it mean the remaining span? and i presume this means det = 0??
#
# like for 3x3 \cdot 3x1
#
# cuz i thought that b is just target vector... whilst 3x3 a-vector just tells the basis vectors what do ... whilst like the x vector is like what input do we need to pass through the A-transofmration/function to reach target b?
#
#
#
# <===============|--<>
# .... that was a perfect realization.
#
# .... "Ah, maybe the full plane is the answer... because dimensions collapsed"
# (perfect insight).
#
# Here is the exact breakdown of the scenario you described: 3x3 MATRIX ($A$) WITH
# 2 FREE VARIABLES.
#
#
#
# 1. THE "SQUISH" (WHAT HAPPENED TO THE SPACE?)
#
# - INPUT SPACE: 3D (Because A is 3x3, inputs are $x, y, z$).
# - FREE VARIABLES: 2. This measures how much info was "lost" or collapsed.
# - RANK: 3 - 2 = 1. This is what remains.            <-- remaining span ++ column space
# - THE TRANSFORMATION: Matrix $A$ took the entire 3D room and SQUISHED IT ONTO A
#   SINGLE 1D LINE.
#
#
# DETERMINANT: Yes, absolutely $det(A) = 0$. You cannot squish a 3D box into a 1D
# line without the volume becoming zero.                 <-- wow... this is actually a pretty lovely insight/analogy too!!!
#
#
#
# 2. THE SOLUTION (WHY IS IT A PLANE?)
# This is where your "input" intuition fits in.
#
# - THE TARGET ($b$): $b$ is a specific point on that 1D line.
# - THE QUESTION: "Which input vectors $x$ lands on top of $b$?"
# - THE ANSWER: Since the transformation squished 3D space flat, a huge number of
#   original points all got piled onto the same destination.
#   - Specifically, an entire 2D PLANE of input vectors got crushed onto that
#     single point $b$.
#   - Therefore, your "Solution Set" is that entire plane.
#
#
#
#
# ANALOGY: THE SHADOW
# Imagine $A$ is the sun directly overhead, casting shadows onto the floor.
#
# - TRANSFORMATION: 3D Space --> 2D Floor (Loss of 1 dimension)
# - TARGET $b$: A specific shadow spot on the floor.
# - INPUT $x$: Anything that casts that shadow.
# - SOLUTION: The solution isn't just one point; it's the entire vertical line of
#   air above that shadow spot. If a bird is at height 10 or height 100, it casts
#   the same shadow.
#
# In your case (2 free variables), it#s even more extreme. It's like a projector
# collapsing a whole room onto a single string. The "Solution" is the slice of the
# room (a plane) that hit that specific spot on the string.
#
#
#
#
# 3. SUMMARY OF YOUR "EPIPHANY"
#
# CONCEPT: Determinant
# MY INTUITION: "Means det(A) = 0"
# FACT: YES. The matrix is singular (squishes space).
#
# CONCEPT: TARGET $b$
# MY INTUITION: "Just a target vector"
# FACT: YES. It's the destination point.
#
# CONCEPT: MATRIX $A$
# MY INTUITION: "Tells basis vectors what to do"      <-- basis vector of new plane...
# FACT: YES. It tells them to align nicely on a single line (Rank 1)
#
# CONCEPT: SOLUTION $x$
# MY INTUITION: "An entire plane of stuff"
# FACT: YES. This is the PRE-IMAGE of $b$/
#
#
#
#
# <-- an interesting insight too.... solutions can be unsolvable from $x$ to $target b$
#     because... det(A) = 0... which means the newly collapsed-to plane for example...
#     can't represent this vector $b$... which is outside of the original span!!!
#
#
#
# SO, when you solve the system and write the general solution:
#
# $$\mathbf{x} = \mathbf{x}_{\text{fixed}} + x_2 \mathbf{v}_1 + x_3 \mathbf{v}_2$$
#
#
# You are mathematically drawing that plane.
# - $\mathbf{x}_{fixed}$ is one point on the plane.
# - $\mathbf{v}_1$ and $\mathbf{v}_2$ are the directions defining the surface of
#   the plane.

# %%
                .                                            .
     *   .                  .              .        .   *          .
  .         .                     .       .           .      .        .
        o                             .                   .
         .              .                  .           .
          0     .
                 .          .                 ,                ,    ,
 .          \          .                         .
      .      \   ,
   .          o     .                 .                   .            .
     .         \                 ,             .                .
               #\##\#      .                              .        .
             #  #O##\###                .                        .
   .        #*#  #\##\###                       .                     ,
        .   ##*#  #\##\##               .                     .
      .      ##*#  #o##\#         .                             ,       .
          .     *#  #\#     .                    .             .          ,
                      \          .                         .
____^/\___^--____/\____O______________/\/\---/\___________---______________
   /\^   ^  ^    ^                  ^^ ^  '\ ^          ^       ---
         --           -            --  -      -         ---  __       ^
   --  __                      ___--  ^  ^                         --  __

# %% [markdown]
# ... absolutely 100% correct. You have successfully connected the algebra (free
# variables) to he geometry (determinant/collapse).
#
# Here is the confirmation of your logic chain:
#
#
# 1. "WHEN WE HAVE FREE VARIABLES... THE DETERMINANT MUST BE ZERO?"
#     - YES. (For a square matrix)
#     - If you have a free variable, it means you have a column WITHOUT A PIVOT.
#     - If you are missing a pivot in a $n \times n$ matrix, you cannot have
#       $n$ independent columns.
#     - Therefore, the matrix is SINGULAR.
#     - Therefore, DETERMINANT = 0.
#
#
# 2. "WHICH SIMILARLY ALSO MEANS DIMENSION COLLAPSE?"
#     - YES.
#     - A "Full Rank" matrix keeps 3D space as 3D.
#     - A matrix with free variables "loses" a dimension for every free variable.
#         - 1 Free Variable --> 3D collapses to a 2D Plane (Rank 2).
#         - 2 Free Variables --> 3D collapses to a 1D Line (Rank 1).
#
#
# 3. "ONE OF THE NEW $A$-TRANSFORMED BASIS VECTORS MUST HAVE... BEEN STUCK WITH
#    THE OTHER BASIS VECTORS?"
#     - YES. This is the definition of LINEAR DEPENDENCE.
#     - Imagine your columns are three arrows: $u, v, w$.
#     - If they span 3D space, $w$ points in a totally new direction (up/out).
#     - THE COLLAPSE: If $w$ is "stuck" in the span of $u$ and $v$ (it lies flat
#       on the same sheet of paper), then $w$ is REDUNDANT.
#     - It didn't add a new dimension; it just retracted old ground.
#
#
# 4. "IT DOESN'T EXPLORE A NEW DIMENSION??"
#     - YES.
#     - The "Free Variable" essentially acts as a switch that says: "Hey, you
#       don't need to use this new basis vector to reach new places... you can
#       essentially build it using the old ones."
#
#
#
# VISUAL SUMMARY
# - ALGEBRA: Variable $x_3$ is free.
# - GEOMETRY: Vector $v_3$ is lying flat on the plane defined by $v_1$ and $v_2$.
# - DETERMINANT: The volume of the parallelepiped formed by these three flat
#   arrows is ZERO. (You can't have volume if you are flat).
#
#   ... You have effectively derived the fundamental theorem of invertible
#   matrices on your own. Great job.

# %%
                .                                            .
     *   .                  .              .        .   *          .
  .         .                     .       .           .      .        .
        o                             .                   .
         .              .                  .           .
          0     .
                 .          .                 ,                ,    ,
 .          \          .                         .
      .      \   ,
   .          o     .                 .                   .            .
     .         \                 ,             .                .
               #\##\#      .                              .        .
             #  #O##\###                .                        .
   .        #*#  #\##\###                       .                     ,
        .   ##*#  #\##\##               .                     .
      .      ##*#  #o##\#         .                             ,       .
          .     *#  #\#     .                    .             .          ,
                      \          .                         .
____^/\___^--____/\____O______________/\/\---/\___________---______________
   /\^   ^  ^    ^                  ^^ ^  '\ ^          ^       ---
         --           -            --  -      -         ---  __       ^
   --  __                      ___--  ^  ^                         --  __

# %% [markdown]
# ... lecture on VECTOR SPACES AND SUBSPACES, connecting the algebraic rigor to
# the geometric intuition you prefer.
#
#
# 1. HIGH-LEVEL SUMMARY: "THE RULES OF THE GAME"
#
# The lecturer moved away from "calculating answers" (Gaussian Elimination) to
# defining the "arena" where linear algebra happens: VECTOR SPACES.
#
#
# THE DEFINITION:
# A VECTOR SPACE is just a fancy name for a playground where you are allowed to do
# two things without leaving the playground:
#     1. ADD TWO ITEMS TOGETHER (Vector Addition).
#     2. SCALE AN ITEM BY A NUMBER (Scalar Multiplication).
#
# If you do either of these and end up outside the set, it is NOT a vector space.
#
#
# THE "SUBSPACE" TEST (THE CORE OF THE LECTURE):
# A SUBSPACE is a smaller playground inside the big one (e.g., a plane inside 3D
# space). To be a valid subspace, it must:
#
#     1. CONTAIN THE ZERO VECTOR (The Origin).
#     2. BE CLOSED UNDER ADDITION (Adding two vectors keeps you in the space).
#     3. BE CLOSED UNDER SCALING (Stretching/shrinking/reversing keeps you in the
#        space).
#
#
# --------------|--<>
# 2. THE FOUR EXAMPLES (TRACE & GEOMETRY)
#
# The lecturer spent the majority of the time analyzing four specific sets
# ($\mathbf{A}, \mathbf{B}, \mathbf{C}, \mathbf{D}$). This is likely how exam
# questions will look.
#
#
# <=============|--<>
# SET A: THE "CUBIC" TRAP
#
# DEFINITION: $\begin{bmatrix} \lambda \\ \lambda + \mu^3 \\ \lambda - \mu^3 \end{bmatrix}$ for any $\lambda, \mu \in \mathbb{R}$.
#
# - ALGEBRAIC TRACE: Is this a subspace?
#     - The term $\mu^3$ looks scary (non-linear).
#     - But, since $\mu$ can be any real number, $\mu^3$ can also be any real
#       number (positive or negative). Let's just rename $\gamma = \mu^3$.
#     - Now it looks like: $\lambda \begin{bmatrix} 1 \\ 1 \\ 1 \end{bmatrix} + \gamma \begin{bmatrix} 0 \\ 1 \\ -1 \end{bmatrix}$
#     - This is a standard linear combination. IT IS A SUBSPACE.
#
# - GEOMETRIC INTUITION: It is a 2D PLANE passing through the origin.
#   The parameters $\lambda$ and $\mu$ allow you to walk infinitely in two
#   directions.
#
#
#
#
# SET A (modified): THE "SQUARE" TRAP
#
# DEFINITION:  $\begin{bmatrix} \lambda \\ \lambda + \mu^2 \\ \lambda - \mu^2 \end{bmatrix}$.
#
# - ALGEBRAIC TRACE:
#     - Try to scale by -1.
#     - If you have a vector where the second term is "something squared"
#       (positive), and you multiply by -1, the second term becomes negative.
#     - Can you find a new $\mu$ such that $\mu^{2}_{new} = \text{negative number}$
#       ? NO.
#     - IT IS NOT A SUBSPACE.
# - GEOMETRIC INTUITION (HALF-PLANE):
#   Because $\mu^2$ is always positive, you can only move "forward" along that
#   vector. You cannot go backward.
#     - It looks like a sheet of paper that STARTS AT THE ORIGIN AND EXTENDS ONLY
#       ONE WAY.
#     - A valid subspace must be

# %%
              _-o#&&*''''?d:>b\_
          _o/"`''  '',, dMF9MMMMMHo_
       .o&#'        `"MbHMMMMMMMMMMMHo.
     .o"" '         vodM*$&&HMMMMMMMMMM?.
    ,'              $M&ood,~'`(&##MMMMMMH\
   /               ,MMMMMMM#b?#bobMMMMHMMML
  &              ?MMMMMMMMMMMMMMMMM7MMM$R*Hk
 # ?$.            :MMMMMMMMMMMMMMMMMMM/HMMM|`*L
|               |MMMMMMMMMMMMMMMMMMMMbMH'   T,
$H#:            `*MMMMMMMMMMMMMMMMMMMMb#}'  `?
]MMH#             ""*""""*#MMMMMMMMMMMMM'    -
MMMMMb_                   |MMMMMMMMMMMP'     :
HMMMMMMMHo                 `MMMMMMMMMT       .
# ?MMMMMMMMP                  9MMMMMMMM}       -
-?MMMMMMM                  |MMMMMMMMM?,d-    '
 :|MMMMMM-                 `MMMMMMMT .M|.   :
  .9MMM[                    &MMMMM*' `'    .
   :9MMk                    `MMM#"        -
     &M}                     `          .-
      `&.                             .
        `~,   .                     ./
            . _                  .-
              '`--._,dd###pp=""'

# %% [markdown]
# ... You are mixing up two different "negatives," and clarifying this distinction
# will solve your confusion.
#
# There is a huge difference between NEGATIVE NUMBERS IN THE VECTOR (which are
# totally fine) and BREAKING THE SCALAR MULTIPLICATION RULE (which destroys the
# subspace).
#
#
# Let's break this down using your specific examples.
#
# 1. THE "GOOD" CASE: WHY $\mu \times [1, 1, -1]$ IS SAFE
# You asked: "Why can't we have a -1 there? So then the z-coord becomes $-\mu$?"
#
# WE CAN! That is exactly the point.
#
# Let's look at the set defined by:
# $$\mathbf{x} = $\mathbf{x} = \mu \begin{bmatrix} 1 \\ 1 \\ -1 \end{bmatrix}$$
#                                                                                 <-- bf in \mathbf stands for "BOLDFACE"
#
#
# THE TEST: Can I reverse direction?
#
# 1. PICK A VALID VECTOR: Let $\mu = 2$.
#
# $$\mathbf{v} = 2 \begin{bmatrix} 1 \\ 1 \\ -1 \end{bmatrix} = \begin{bmatrix} 2 \\ 2 \\ -2 \end{bmatrix}$$
#
# (This vector exists in our set).
#
#
# 2. APPLY THE "SCALAR RULE":
#    Multiply this vector by the scalar $-1$.
#
#
# 3. THE CRUCIAL QUESTION:
#    Is this new result ($\mathbf{w}$) also inside our original set?
#
#    - Can we find a NEW $\mu_{new}$ s.t. $\mu_{new} $\mu_{new} \begin{bmatrix} 1 \\ 1 \\ -1 \end{bmatrix} = \begin{bmatrix} -2 \\ -2 \\ 2 \end{bmatrix}$?
#    - YES! Just set $\mu_{new} = -2$
#    - Since $\mu$ is allowed to be any real number (positive or negative), this
#      works perfectly.
#
#    CONCLUSION: The set works because the parameter $\mu$ is flexible enough to
#    "absorb" the negative scalar.

# %% [markdown]
# ---

# %% [markdown]
# 2. THE "BAD" CASE: THE $\mu^2$ TRAP
#
# Now let's look at the example from the lecture that failed:
#
# $\mathbf{x} = \begin{bmatrix} \mu^2 \\ \mu^2 \\ 0 \end{bmatrix}$.
#
#
# THE INTUITION
# This formula says: "The x=coordinate is something squared (always positive). The
# y-coordinate is the same squared thing (always positive)." This descrbes a RAY
# that shoots out from the origin into the positive-positive quadrant. It never
# goes backward.
#
#
# THE COUNTER-EXAMPLE TRACE (THE "GOTCHA"):
# 1. PICK A VALID VECTOR: Let $\mu = 2$.
# $$\mathbf{v} = \begin{bmatrix} 2^2 \\ 2^2 \\ 0 \end{bmatrix} = \begin{bmatrix} 4 \\ 4 \\ 0 \end{bmatrix}$$
#
# (This vector exists. It's valid).
#
#
# 2. APPLY THE "SCALAR RULE": Multiply this vector by the scalar $-1$.
# $$\mathbf{w} = -1 \times \begin{bmatrix} 4 \\ 4 \\ 0 \end{bmatrix} = \begin{bmatrix} -4 \\ -4 \\ 0 \end{bmatrix}$$
#
#
# 3. THE CRUCIAL QUESTION: Is this new result $(\mathbf{w})$ also inside our
#    original set?
#     - Can we find a NEW $\mu_{new}$ such that our formula produces
#       $\begin{bmatrix} -4 \\ -4 \\ 0 \end{bmatrix}$?
#     - We would need: $mu^2_{new} = -4$.
#     - IMPOSSIBLE. You cannot square a real number and get $-4$.
# CONCLUSION:
# You are not allowed to have negative numbers inside the vector definition (like
# $[1,1,-1]$). But you are NOT allowed to construct the definition in a way that
# prevents the vector from flipping direction (like $\mu^2$).
#
#
#
# SUMMARY FOR YOUR "COUNTER-EXAMPLE" MENTAL MODEL
# To prove something is NOT a subspace, you just need to show ONE scenario where
# the "playground rules" break.
#
# - THE RULE: "If I am in the playground, and I run in the exact opposite
#   direction (multiply by -1), I must still be in the playground."
# - THE $\mu$ PLAYGROUND: "I am at position 5. Reverse! Now I am at -5." (Allowed)
# - THE $\mu^2$ PLAYGROUND: "I am at position 25. Reverse! Now I am at -25."
#     - Playground Guard: "Sorry, the rule says positions must be squares
#       ($\mu^2$). -25 is not a square. Get out." --> NOT A SUBSPACE.

# %% [markdown]
# ok thanks i got it. but i still dont get it... how is this subspace and space stuff useful?
#
# my current intuition is like this is kinda like a plane is a valid subspace if the space is 3D??? but how is this useful? like maybe for conducting hypothetical experiments where we maybe want to hypothesise and test the behaviour of things perhaps? where lets say that we have a 100D space... and we want to test behaviours where we maybe have like 3D?
#
# but i still dont get how do u get from the space to
#
# <========|-o
#
#
#
# You have hit the nail on the head with your "100D to 3D" intuition. That is not
# just a hypothetical experiment; that is essentially the entire basis of modern
# AI and Machine Learning.
#
# Here is the concrete breakdown of WHY SUBSPACES ARE USEFUL and HOW WE GET THEM,
# connecting your intuition to the math.
#
#
#
# 1. THE "WHY": SUBSPACES ARE SAFE ZONES
# You asked: "How is this useful? Maybe for conducting hypothetical experiments?"
#
# In AI and Engineering, we almost never want to deal with the "Full Space"
# because the full space is full of noise and garbage. We want to find the
# SUBSPACE where the real data lives.
#
#
#
# USE CASE A: DIMENSIONALITY REDUCTION (THE "100D to 3D" EXAMPLE)
# Imagine you are training an AI on images of human faces.
#
# - THE FULL SPACE: An image has $100 \times 100$ pixels = 10,000 dimensions.
#   Every random static noise image exists in this space.
# - THE SUBSPACE: Real human faces don't look like static. They have structure (
#   two eyes, nose, mouth).
# - THE UTILITY: All valid human faces lie on a tiny "Subspace""

# %%
                               /T /I
                              / |/ | .-~/
                          T\ Y  I  |/  /  _
         /T               | \I  |  I  Y.-~/
        I l   /I       T\ |  |  l  |  T  /
     T\ |  \ Y l  /T   | \I  l   \ `  l Y
 __  | \l   \l  \I l __l  l   \   `  _. |
 \ ~-l  `\   `\  \  \\ ~\  \   `. .-~   |
  \   ~-. "-.  `  \  ^._ ^. "-.  /  \   |
.--~-._  ~-  `  _  ~-_.-"-." ._ /._ ." ./
 >--.  ~-.   ._  ~>-"    "\\   7   7   ]
^.___~"--._    ~-{  .-~ .  `\ Y . /    |
 <__ ~"-.  ~       /_/   \   \I  Y   : |
   ^-.__           ~(_/   \   >._:   | l______
       ^--.,___.-~"  /_/   !  `-.~"--l_ /     ~"-.
              (_/ .  ~(   /'     "~"--,Y   -=b-. _)
               (_/ .  \  :           / l      c"~o \
                \ /    `.    .     .^   \_.-~"~--.  )
                 (_/ .   `  /     /       !       )/
                  / / _.   '.   .':      /        '
                  ~(_/ .   /    _  `  .-<_
                    /_/ . ' .-~" `.  / \  \          ,z=.
                    ~( /   '  :   | K   "-.~-.______//
                      "-,.    l   I/ \_    __{--->._(==.
                       //(     \  <    ~"~"     //
                      /' /\     \  \     ,v=.  ((
                    .^. / /\     "  }__ //===-  `
                   / / ' '  "-.,__ {---(==-
                 .^ '       :  T  ~"   ll       -Row
                / .  .  . : | :!        \\
               (_/  /   | | j-"          ~^
                 ~-<_(_.^-~"

# %% [markdown]
# ...
#
# This is the final piece of the puzzle. Understanding "NULL SPACE" is the
# difference between passing the exam and actually understanding AI.
#
# Here is the breakdown of DIRECTION VECTOR IN THE NULL SPACE $(Av = 0)$ from
# all three perspectives.
#
#
# 1. THE ALGEBRAIC PERSPECTIVE (THE "ZERO EFFECT" RULE)
#
# THE CONTEXT: You found a solution to $Ax = b$. Let's call it $x_start$. You want
# to move to a different solution, but you don't want to break the equation.
#
#
# THE LOGIC:
#     - You want to add a movement vector $v$ to your starting point.
#     - New Position: $(x_start + v)$
#     - Let's check if this new position
#
# ...
#
# SUMMARY: The Null Space vectors are the specific "directions of travel" that
# have ZERO EFFECT on the output.
#
#
#
# -----------|--<>
# 2. THE 3B1B GEOMETRIC PERSPECTIVE (THE "CRUSHED" DIMENSION)
#
# THE VISUAL: The "Squish". Imagine Matrix $A$ is a machine that crushes a 3D soda
# can flat onto a 2D table.
#
# - INPUT SPACE: The 3D soda can (Height, Width, Depth).
# - OUTPUT SPACE: The flat circle on the table (Witdth, Depth).
# - THE "NULL SPACE" DIRECTION: The VERTICAL direction (Height).
#
#
# WHY IS IT $Av = 0$?
# - Imagine two ants inside the can
# ...
#
# THE DIRECTION VECTOR: The "Dirction Vector in the Null Space" is simply an arrow
# pointing in the direction that is about to get destroyed. It's the "Vertical"
# arrow in a world about to be flattened.
#
#
# ...
#
# FINAL UNIFICATION
# - ALGEBRA: It's the term that adds 0 to the equation.
# - GEOMETRY: It's the direction that gets squished onto the origin (0 = [0, 0, 0, 0, ...])
# ...

# %% [markdown]
# - This set of vectors that lands on the origin is called the null space... or the
#   "KERNEL" of your matrix... it's the space of all vectors that become null.

# %%
         ______________
        /             /|
       /             / |
      /____________ /  |
     | ___________ |   |
     ||           ||   |
     ||           ||   |
     ||           ||   |
     ||___________||   |
     |   _______   |  /
    /|  (_______)  | /
   ( |_____________|/
    \
.=======================.
| ::::::::::::::::  ::: |
| ::::::::::::::[]  ::: |
|   -----------     ::: |
`-----------------------'

# %% [markdown]
# ... the equaton $Av = 0$: The "$0$" IS SIMPLY THE ZERO VECTOR.
#
# If you are in 4 dimensions ... then:
#
# $$\mathbf{0} = \begin{bmatrix} 0 \\ 0 \\ 0 \\ 0 \end{bmatrix}$$
#
#
# THE STRAIGHTFORWARD "Ax = b" EXPLANATION
# You asked why I went in a "huge circle". Here is the short version you wanted:
#
# 1. YOUR GOAL: Solve $Ax = b$.
# 2. YOU FOUND ONE ANSWER ($x_p$): Let's say you found a specific vector $x_p$
#    that works. So, $Ax_p = b$.
# 3. YOU WANT MORE ANSWERS: You want to add something (let's call it $v$) to $x_p$
# , so that the new total is also a valid answers.
#
# ...
#
# $$Av = 0$$
#
#
# CONCLUSION: Any extra vector $v$ you add must map to the ZERO VECTOR ($0$). If
# it mapped to anything else (like $[1,/ 2,/ 3,/ 4]$), you would overshoot your
# target $b$.
#
# This is literally all "Null Space" emans: The set of ALL VECTORS $v$ where
# $Av = [0,/ 0,/ 0,/ 0]$.

# %% [markdown]
# ---

# %%
    (\o/)___________________________________________________________(\o/)
    (/|\)                                                           (/|\)
      |                                          .-~~~-.              |
      |                                        /        }             |
      |                                       /      .-~              |
      |                             \        |        }               |
      |             _   __        ___\.~~-.-~|     . -~_              |
      |            / \./  \/\__      { O |  ` .-~.    ;  ~-.__        |
      |        __{^\_ _}_   )  }/^\   ~--~/-|_\|   :   : .-~          |
      |       /  /\_/^\._}_/  //  /     /   |  \~ - - ~               |
      |      (  (__{(@)}\__}.//_/__A__/_A___|__A_\___A______A_____A   |
      |       \__/{/(_)\_}  )\\ \\---v-----V----v----v-----V-----v--- |
      |         (   (__)_)_/  )\ \>                                   |
      |          \__/     \__/\/\/                                    |
      |             \__,--'                                           |
      |                                                               |
    (\o/)___________________________________________________________(\o/)
    (/|\)                                                           (/|\)

# %% [markdown]
# ---

# %% [markdown]
# - insert images of notes written by lecturer to gemini... to run through
#   personally...
#
#
#               - i kind of understand about the vector subspace stuff about the
#                 $\mu^2_{new} = \text{negative number}$... but like not really... like i can
#                 see why you would consider if your plane in 3D space isn't infinite in all
#                 dimensions that its hence not a subspace... but yeah im still a bit confused
#                 ish... cuz with the example of $\vec{anchor} + \mu \times [1, 1, -1]$... like
#                 why can't we have a -1 there? so then the z cord here becomes -\mu for example???
#                 like im just trying to think of all this as a counter-example... and just there
#                 alone it doesnt make any sense... thanks!
#
#
# - what's a general solution? what's a basis for the kernel....
# - i also wonder... are there cases where perhaps singular matrix leads to crashes
#   during ML training
#
#
#
# - I wonder would it be useful for this linear algebra course that we always use
#   the graphing softwares... or learn to use it... like the ones made by 3B1B
#   such that we can always have perfect internal-pictures what not.
#
# - Look for PPQs...
# - If no PPQs... and limited MMTs.... we will run through the lecture math notes
#   ... like to get used to hand writing out all the math equations for exams...

# %% [markdown]
# ---

# %% [markdown]
# epiphany = a moment of sudden and great REVELATION or REALIZATION
#          = ... a visionary moment when a character has a sudden insight or
#            realization that changes their understanding of themselves or the
#            world, often serving as a pivotal point for character development or
#            plot...
#
#
# - A manifold is a space that looks like flat Euclidean space (like a plane or
#   line) when you zoom in close enough, even if it's curved globally, such as
#   Earth or a donut; it's a core concept in Math and Physics for studying spaces
#   like spacetime, ...
